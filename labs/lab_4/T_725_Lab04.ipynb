# %% [markdown]
# # T-725 Natural Language Processing: Lab 4
# In today's lab, we will be working with part-of-speech tagging, parsing, and chunking.
#
# To begin with, do the following:
# * Select `"File" > "Save a copy in Drive"` to create a local copy of this notebook that you can edit.
# * Select `"Runtime" > "Run all"` to run the code in this notebook.

# %% [markdown]
# ## Setting up
# Let's start off by installing the `svgling` library for drawing syntax trees, as well as defining a function to evaluate the grammars that we will be creating in today's lab assignment.

# %%
# !pip install svgling
# Out:
# Requirement already satisfied: svgling in ./venv/lib/python3.10/site-packages (0.3.1)
# Requirement already satisfied: svgwrite in ./venv/lib/python3.10/site-packages (from svgling) (1.4.3)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Compare trees generated by a parser to correct trees

def evaluate_parser(parser, sentences, correct):
  correct_trees = [nltk.Tree.fromstring(t) for t in correct]
  num_sentences = len(sentences)

  for num, (sent, correct_tree) in enumerate(zip(sentences, correct_trees)):
    print(f">{sent}\n")

    error = None
    print_tree = False

    try:
      my_trees = list(parser.parse(sent.split()))
    except ValueError as e:
      print(e)
      my_trees = []

    if len(my_trees) > 1:
      error = f"Generated {len(my_trees)} trees (should only generate one)!"
    elif len(my_trees) == 0:
      error = "Couldn't parse sentence."
    else:
      my_tree = my_trees[0]
      if my_tree != correct_tree:
        error = "Generated an incorrect tree"
        print_tree = True

    if error:
      print(error)

      if print_tree:
        print("\nYour tree:")
        my_tree.pretty_print()

      print("\nCorrect tree:")
      correct_tree.pretty_print()
    else:
      print("Correct!\n")

    if num != num_sentences - 1:
      print("============================")

# %% [markdown]
# ## Context free grammars (CFG) in NLTK
#
# [Example 3.1](https://www.nltk.org/book/ch08.html#sec-context-free-grammar) in chapter 8 of the NLTK book shows how we define a context free grammar (CFG) and use it to parse sentences.

# %%
import nltk

grammar1 = nltk.CFG.fromstring("""
  S -> NP VP
  VP -> V NP | V NP PP
  PP -> P NP
  V -> "saw" | "ate" | "walked"
  NP -> "John" | "Mary" | "Bob" | Det N | Det N PP
  Det -> "a" | "an" | "the" | "my"
  N -> "man" | "dog" | "cat" | "telescope" | "park"
  P -> "in" | "on" | "by" | "with"
  """)

sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar1)
for tree in rd_parser.parse(sent):
  print(tree)
# Out:
# (S (NP Mary) (VP (V saw) (NP Bob)))

# %% [markdown]
# ## Visualizing parse trees with NLTK
# We can use NLTK to draw a graphical diagram of a syntax tree. Unfortunately, this functionality does not work on Google Colab. We can still print it as text:

# %%
from nltk import Tree

t = Tree.fromstring('(S (NP this tree) (VP (V is) (ADJ pretty)))')

# NLTK won't draw the tree if we're using Google Colab
# t.draw()

# But we can still print a text diagram
t.pretty_print()
# Out:
#                S
#        ________|_______
#       |                VP
#       |             ___|____
#       NP           V       ADJ
#   ____|___         |        |
# this     tree      is     pretty

# %% [markdown]
# We can also use a different library, `svgling`, to draw trees:

# %%
import svgling

svgling.draw_tree(t)
# Out:
# TreeLayout(Tree('S', [Tree('NP', ['this', 'tree']), Tree('VP', [Tree('V', ['is']), Tree('ADJ', ['pretty'])])]))

# %% [markdown]
# ## Probabilistic context free grammar (PCFG) in NLTK
# [Example 6.4](https://www.nltk.org/book/ch08.html#code-pcfg1) in chapter 8 of the NLTK book shows how to define a probabilistic context free grammar (PCFG) and use it to produce the most likely tree for a given sentence. Note that the productions for each category must add up to 1.0.

# %%
import nltk

grammar = nltk.PCFG.fromstring("""
    S    -> NP VP              [1.0]
    VP   -> TV NP              [0.4]
    VP   -> IV                 [0.3]
    VP   -> DatV NP NP         [0.3]
    TV   -> 'saw'              [1.0]
    IV   -> 'ate'              [1.0]
    DatV -> 'gave'             [1.0]
    NP   -> 'telescopes'       [0.8]
    NP   -> 'Jack'             [0.2]
    """)

viterbi_parser = nltk.ViterbiParser(grammar)

for tree in viterbi_parser.parse(['Jack', 'saw', 'telescopes']):
  print(tree)
# Out:
# (S (NP Jack) (VP (TV saw) (NP telescopes))) (p=0.064)

# %% [markdown]
# This is equivalent to:

# %%
grammar = nltk.PCFG.fromstring("""
    S    -> NP VP [1.0]
    VP   -> TV NP [0.4] | IV [0.3] | DatV NP NP [0.3]
    TV   -> 'saw' [1.0]
    IV   -> 'ate' [1.0]
    DatV -> 'gave' [1.0]
    NP   -> 'telescopes' [0.8] | 'Jack' [0.2]
    """)

viterbi_parser = nltk.ViterbiParser(grammar)

for tree in viterbi_parser.parse(['Jack', 'saw', 'telescopes']):
  print(tree)
# Out:
# (S (NP Jack) (VP (TV saw) (NP telescopes))) (p=0.064)

# %% [markdown]
# ## Chunking with NLTK
# NLTK's taggers can be used for more than just assigning part-of-speech tags to tokens. They can also be trained to assign chunk tags to chunks. [Example 3.1](https://www.nltk.org/book/ch07.html#code-unigram-chunker) in chapter 7 of the NLTK book shows how to build a chunker with a unigram tagger:

# %%
class UnigramChunker(nltk.ChunkParserI):
    def __init__(self, train_sents):
        train_data = [[(t, c) for w, t, c in nltk.chunk.tree2conlltags(sent)]
                      for sent in train_sents]

        self.tagger = nltk.UnigramTagger(train_data)

    def parse(self, sentence):
        pos_tags = [pos for (word,pos) in sentence]
        tagged_pos_tags = self.tagger.tag(pos_tags)
        chunktags = [chunktag for (pos, chunktag) in tagged_pos_tags]
        conlltags = [(word, pos, chunktag) for ((word,pos),chunktag)
                     in zip(sentence, chunktags)]
        return nltk.chunk.conlltags2tree(conlltags)

# %% [markdown]
# We can train it and evaluate it on the CoNLL 2000 corpus, which contains chunk IOB tags (I-inside, O-outside, B-begin) as well as POS tags.

# %%
from nltk.corpus import conll2000
nltk.download('conll2000')
nltk.download('averaged_perceptron_tagger')

test_sents = conll2000.chunked_sents('test.txt', chunk_types=['NP'])
train_sents = conll2000.chunked_sents('train.txt', chunk_types=['NP'])

chunker = UnigramChunker(train_sents)
# Out:
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /home/administrator/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/administrator/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# Now that we've trained an NP chunker, we can try chunking a sentence:

# %%
import svgling
sentence = nltk.pos_tag('The little yellow dog barked at the cat.'.split())

tree = chunker.parse(sentence)
print(tree)

# Note that we can't pretty_print() partial trees, but we can still draw them
# using svgling
svgling.draw_tree(tree)
# Out:
# (S
#   (NP The/DT little/JJ yellow/JJ dog/NN)
#   barked/VBD
#   at/IN
#   (NP the/DT cat./NN))
# TreeLayout(Tree('S', [Tree('NP', [('The', 'DT'), ('little', 'JJ'), ('yellow', 'JJ'), ('dog', 'NN')]), ('barked', 'VBD'), ('at', 'IN'), Tree('NP', [('the', 'DT'), ('cat.', 'NN')])]))

# %% [markdown]
# We can also see how well the chunker performs by evaluating it on the test set:

# %%
print(chunker.evaluate(test_sents))
# Out:
# /tmp/ipykernel_13860/2809867139.py:1: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(chunker.evaluate(test_sents))
# ChunkParse score:
#     IOB Accuracy:  92.9%%
#     Precision:     79.9%%
#     Recall:        86.8%%
#     F-Measure:     83.2%%

# %% [markdown]
# # Assignment
# Answer the following questions and hand in your solution in Canvas before 8:30 Monday morning, September 25th. Remember to save your file before uploading it.

# %% [markdown]
# ## Question 1
# Part-of-Speech Tagging
#
# Complete the following tasks:
# 1. Use `gutenberg.sents(filename)` to get the tokenized sentences of *The Innocence of Father Brown* by G. K. Chesterton (`chesterton-brown.txt`).
# 2. Tag the sentences using `nltk.pos_tag_sents(tokenized_sentences)`.
# 3. Use a list comprehension to create a single list with all the tags.
# 4. Use `nltk.FreqDist()` to count the tags, and generate a frequency list (with all the tags) using `.most_common()`.

# %%
from nltk.corpus import gutenberg
nltk.download('gutenberg')

# Required for nltk.pos_tag_sents()
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     /home/administrator/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/administrator/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/administrator/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Your solution here
tokenized_sentences = gutenberg.sents('chesterton-brown.txt')
tagged_tokenized_sentences = nltk.pos_tag_sents(tokenized_sentences)
all_tags = [tag for sentence in tagged_tokenized_sentences for _, tag in sentence]
tag_freq = nltk.FreqDist(all_tags)
tag_freq.most_common()
# Out:
# [('NN', 12969),
#  ('IN', 9389),
#  ('DT', 8447),
#  ('JJ', 5935),
#  ('PRP', 5485),
#  ('VBD', 5168),
#  ('RB', 4475),
#  (',', 4069),
#  ('NNP', 3664),
#  ('CC', 3292),
#  ('.', 2918),
#  ('NNS', 2582),
#  ('VB', 2419),
#  ('VBN', 1787),
#  (':', 1745),
#  ('PRP$', 1571),
#  ('VBP', 1510),
#  ('TO', 1391),
#  ('VBG', 1239),
#  ('VBZ', 964),
#  ('MD', 829),
#  ("''", 614),
#  ('CD', 504),
#  ('RP', 419),
#  ('WP', 413),
#  ('WDT', 410),
#  ('WRB', 359),
#  ('POS', 298),
#  ('JJR', 222),
#  ('EX', 202),
#  ('RBR', 182),
#  ('JJS', 150),
#  ('PDT', 122),
#  ('(', 57),
#  ('``', 50),
#  ('RBS', 49),
#  (')', 43),
#  ('SYM', 31),
#  ('FW', 28),
#  ('UH', 26),
#  ('NNPS', 19),
#  ('WP$', 17)]

# %% [markdown]
# ## Question 2
# Add to `q1_grammar` below until the sentence can be correctly parsed.

# %%
q1_grammar = nltk.CFG.fromstring("""
    S  -> NP VP
    NP -> NP PP | N
    VP -> V ADJ
    PP -> P NP
    N -> 'sunsets' | 'mars'
    V -> 'are'
    P -> 'on'
    ADJ -> 'blue'
  """)

q1_parser = nltk.ChartParser(q1_grammar)

# Evaluate the parser
q1_sents = ["sunsets on mars are blue"]
q1_correct = ["(S (NP (NP (N sunsets)) (PP (P on) (NP (N mars)))) (VP (V are) (ADJ blue)))"]

evaluate_parser(q1_parser, q1_sents, q1_correct)
# Out:
# >sunsets on mars are blue
#
# Correct!

# %% [markdown]
# ## Question 3
# Make the following changes to `q2_grammar` below:
# 1. Replace the noun category (N) with singular nouns (NN) and plural nouns (NNS).
# 2. Add a category for cardinal numbers (CD).
# 3. Add a category for adverbs (ADV).
# 4. Add a category for personal pronouns (PRP).
#
# Adjust your grammar so that the sentences below are parsed correctly.

# %%
q2_grammar = nltk.CFG.fromstring("""
    S  -> NP VP
    NP -> NP PP | NN | NNS | DT ADJ NN | DT NN | PRP NN | CD ADJ NNS
    VP -> V NP | V PP
    PP -> P NP | ADV P NP
    DT -> 'the'
    NN -> 'venus' | 'planet' | 'earth' | 'sun' | 'life' | 'saturn' 
    NNS -> 'moons'
    ADJ -> 'closest' | 'known'
    V -> 'is' | 'has'
    P -> 'to' | 'through'
    CD -> '82'
    ADV -> 'halfway'
    PRP -> 'its'
  """)

q2_parser = nltk.ChartParser(q2_grammar)

# Facts
q2_facts = [
    "venus is the closest planet to earth",
    "the sun is halfway through its life",
    "saturn has 82 known moons"
]

# Evaluate the parser
q2_correct = [
    "(S (NP (NN venus)) (VP (V is) (NP (NP (DT the) (ADJ closest) (NN planet)) (PP (P to) (NP (NN earth))))))",
    "(S (NP (DT the) (NN sun)) (VP (V is) (PP (ADV halfway) (P through) (NP (PRP its) (NN life)))))",
    "(S (NP (NN saturn)) (VP (V has) (NP (CD 82) (ADJ known) (NNS moons))))"
]

evaluate_parser(q2_parser, q2_facts, q2_correct)
# Out:
# >venus is the closest planet to earth
#
# Correct!
#
# ============================
# >the sun is halfway through its life
#
# Correct!
#
# ============================
# >saturn has 82 known moons
#
# Correct!

# %% [markdown]
# ## Question 4
# Replace the verb category (V) with transitive (TV) and intransitive (IV) verbs and adjust the grammar so that the sentences below are correctly parsed.

# %%
q3_grammar = nltk.CFG.fromstring("""
  S  -> NP VP
  NP -> DT N N | N | CD
  VP -> IV PP PP | TV NP PP
  PP -> P | P NP
  DT -> 'the'
  N -> 'curiosity' | 'rover' | 'mars' | 'nasa' | 'perseverence'
  TV -> 'launched'
  IV -> 'arrived'
  P -> 'on' | 'in'
  CD -> '2012' | '2020'
  """)

q3_parser = nltk.ChartParser(q3_grammar)

# Facts
q3_facts = [
    "the curiosity rover arrived on mars in 2012",
    "nasa launched the perseverence rover in 2020"
]

# Evaluate the parser
q3_correct = [
    "(S (NP (DT the) (N curiosity) (N rover)) (VP (IV arrived) (PP (P on) (NP (N mars))) (PP (P in) (NP (CD 2012)))))",
    "(S (NP (N nasa)) (VP (TV launched) (NP (DT the) (N perseverence) (N rover)) (PP (P in) (NP (CD 2020)))))"
]

evaluate_parser(q3_parser, q3_facts, q3_correct)
# Out:
# >the curiosity rover arrived on mars in 2012
#
# Correct!
#
# ============================
# >nasa launched the perseverence rover in 2020
#
# Correct!

# %% [markdown]
# ## Question 5
# The following grammar produces two trees for the sentence *John saw a man with binoculars*. Each tree represents a different interpretation of the sentence. One tree implies that John used binoculars to see a man, while the other implies that a man with binoculars was seen by John.
#
# Change the grammar into a **probabilistic CFG** and replace the `ChartParser` with a `ViterbiParser`, which only outputs the most probable tree. Adjust the probabilities so that the parser produces the tree that implies that John saw a man who had binoculars.

# %%
q1_grammar = nltk.PCFG.fromstring("""
  S -> NP VP [1.0]
  NP -> N [0.4] | NP PP [0.3] | DT N [0.3]
  VP -> V NP [0.2] | V NP PP [0.8]
  PP -> P NP [1.0]
  V -> "saw" [1.0]
  DT -> "a" [1.0]
  N -> "John" [0.4]| "man" [0.3]| "binoculars" [0.3]
  P -> "with" [1.0]
  """)

sentence = "John saw a man with binoculars".split()

q1_parser = nltk.ViterbiParser(q1_grammar)
trees = q1_parser.parse(sentence)

for tree in trees:
  print(tree)
  tree.pretty_print()
  print()
# Out:
# (S
#   (NP (N John))
#   (VP
#     (V saw)
#     (NP (DT a) (N man))
#     (PP (P with) (NP (N binoculars))))) (p=0.0013824)
#           S
#   ________|_______
#  |                VP
#  |     ___________|________
#  |    |       |            PP
#  |    |       |        ____|______
#  NP   |       NP      |           NP
#  |    |    ___|___    |           |
#  N    V   DT      N   P           N
#  |    |   |       |   |           |
# John saw  a      man with     binoculars

# %% [markdown]
# ## Question 6
# Create a new class, `TrigramChunker`, based on the `UnigramChunker` class defined earlier in the notebook. Modify it so that `self.tagger` is a trigram tagger with a unigram tagger as a backoff (see [5.4 Combining taggers](http://www.nltk.org/book/ch05.html#combining-taggers) in the NLTK book). Train and evaluate your chunker on the CoNLL 2000 corpus (using `train_sents` and `test_sents`, created earlier) and report the results.

# %%
class TrigramChunker(UnigramChunker):
    def __init__(self, train_sents):
        super().__init__(train_sents)
        train_data = [[(t, c) for w, t, c in nltk.chunk.tree2conlltags(sent)]
                      for sent in train_sents]
        assert type(self.tagger) == nltk.UnigramTagger
        self.tagger = nltk.TrigramTagger(train_data, backoff=self.tagger)

# %%
trigram_chunker = TrigramChunker(train_sents)
print(trigram_chunker.evaluate(test_sents))
# Out:
# /tmp/ipykernel_13860/825272790.py:2: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print(trigram_chunker.evaluate(test_sents))
# ChunkParse score:
#     IOB Accuracy:  93.5%%
#     Precision:     82.5%%
#     Recall:        87.1%%
#     F-Measure:     84.7%%

# %% [markdown]
# ## Question 7
# Complete the following tasks:
#
# 1. Create a list of all tagged sentences from `test.txt` in the `conll2000` corpus using its `tagged_sents(filename)` method.
#
# 2. This should return a list of 2012 tagged sentences. You can access a sentence from the list by its index, e.g., `tagged_sents_list[0]` will return the first tagged sentence. Parse any three of the tagged sentences with your chunker and draw the trees using `svgling.draw_tree(tree)`. Note that the tree will only be drawn if the `draw_tree` method is called at the end of the code block.
#
# 3. Compare the trees generated by your chunker to the correct trees in `test_sents` (which contains the same sentences in the same order as those returned by the `tagged_sents` method). Does your chunker make any mistakes? If so, give an example of at least one of those mistakes.

# %%
all_tagged_sentences = conll2000.tagged_sents('test.txt')
assert len(all_tagged_sentences) == 2012

# %%
import random

# %%
# Sentence 1
random.seed(42)
sentence_1_index = random.choice(range(len(all_tagged_sentences)))
print("Chosen index:", sentence_1_index)
sentence_1 = all_tagged_sentences[sentence_1_index]
sentence_1_test = test_sents[sentence_1_index]
tree_1 = trigram_chunker.parse(sentence_1)
print("Generated Tree:", tree_1)
"""
(S
  (NP We/PRP)
  hope/VBP
  (NP the/DT next/JJ head/NN)
  of/IN
  (NP the/DT Civil/NNP Rights/NNP Commission/NNP)
  will/MD
  be/VB
  as/RB
  (NP brave/JJ)
  as/IN
  (NP Mr./NNP Allen/NNP)
  in/IN
  making/VBG
  (NP the/DT case/NN)
  for/IN
  (NP equality/NN)
  of/IN
  (NP civil/JJ rights/NNS)
  ./.)
"""
print("Test Tree:", sentence_1_test)
"""
(S
  (NP We/PRP)
  hope/VBP
  (NP the/DT next/JJ head/NN)
  of/IN
  (NP the/DT Civil/NNP Rights/NNP Commission/NNP)
  will/MD
  be/VB
  as/RB
  brave/JJ
  as/IN
  (NP Mr./NNP Allen/NNP)
  in/IN
  making/VBG
  (NP the/DT case/NN)
  for/IN
  (NP equality/NN)
  of/IN
  (NP civil/JJ rights/NNS)
  ./.)
"""
# Difference Tagging and Parenthesization: (NP brave/JJ) vs brave/JJ
svgling.draw_tree(tree_1)
# Out:
# Chosen index: 1309
# Generated Tree: (S
#   (NP We/PRP)
#   hope/VBP
#   (NP the/DT next/JJ head/NN)
#   of/IN
#   (NP the/DT Civil/NNP Rights/NNP Commission/NNP)
#   will/MD
#   be/VB
#   as/RB
#   (NP brave/JJ)
#   as/IN
#   (NP Mr./NNP Allen/NNP)
#   in/IN
#   making/VBG
#   (NP the/DT case/NN)
#   for/IN
#   (NP equality/NN)
#   of/IN
#   (NP civil/JJ rights/NNS)
#   ./.)
# Test Tree: (S
#   (NP We/PRP)
#   hope/VBP
#   (NP the/DT next/JJ head/NN)
#   of/IN
#   (NP the/DT Civil/NNP Rights/NNP Commission/NNP)
#   will/MD
#   be/VB
#   as/RB
#   brave/JJ
#   as/IN
#   (NP Mr./NNP Allen/NNP)
#   in/IN
#   making/VBG
#   (NP the/DT case/NN)
#   for/IN
#   (NP equality/NN)
#   of/IN
#   (NP civil/JJ rights/NNS)
#   ./.)
# TreeLayout(Tree('S', [Tree('NP', [('We', 'PRP')]), ('hope', 'VBP'), Tree('NP', [('the', 'DT'), ('next', 'JJ'), ('head', 'NN')]), ('of', 'IN'), Tree('NP', [('the', 'DT'), ('Civil', 'NNP'), ('Rights', 'NNP'), ('Commission', 'NNP')]), ('will', 'MD'), ('be', 'VB'), ('as', 'RB'), Tree('NP', [('brave', 'JJ')]), ('as', 'IN'), Tree('NP', [('Mr.', 'NNP'), ('Allen', 'NNP')]), ('in', 'IN'), ('making', 'VBG'), Tree('NP', [('the', 'DT'), ('case', 'NN')]), ('for', 'IN'), Tree('NP', [('equality', 'NN')]), ('of', 'IN'), Tree('NP', [('civil', 'JJ'), ('rights', 'NNS')]), ('.', '.')]))

# %%
# Sentence 2
random.seed(41)
sentence_2_index = random.choice(range(len(all_tagged_sentences)))
assert sentence_2_index != sentence_1_index
print("Chosen index:", sentence_2_index)
sentence_2 = all_tagged_sentences[sentence_2_index]
sentence_2_test = test_sents[sentence_2_index]
tree_2 = trigram_chunker.parse(sentence_2)
print("Generated Tree:", tree_2)
"""
(S
  In/IN
  (NP major/JJ market/NN activity/NN)
  :/:
  (NP Treasury/NNP bond/NN prices/NNS)
  fell/VBD
  ./.)
"""
print("Test Tree:", sentence_2_test)
"""
(S
  In/IN
  (NP major/JJ market/NN activity/NN)
  :/:
  (NP Treasury/NNP bond/NN prices/NNS)
  fell/VBD
  ./.)
"""
# Same Trees
svgling.draw_tree(tree_2)
# Out:
# Chosen index: 780
# Generated Tree: (S
#   In/IN
#   (NP major/JJ market/NN activity/NN)
#   :/:
#   (NP Treasury/NNP bond/NN prices/NNS)
#   fell/VBD
#   ./.)
# Test Tree: (S
#   In/IN
#   (NP major/JJ market/NN activity/NN)
#   :/:
#   (NP Treasury/NNP bond/NN prices/NNS)
#   fell/VBD
#   ./.)
# TreeLayout(Tree('S', [('In', 'IN'), Tree('NP', [('major', 'JJ'), ('market', 'NN'), ('activity', 'NN')]), (':', ':'), Tree('NP', [('Treasury', 'NNP'), ('bond', 'NN'), ('prices', 'NNS')]), ('fell', 'VBD'), ('.', '.')]))

# %%
# Sentence 3
random.seed(40)
sentence_3_index = random.choice(range(len(all_tagged_sentences)))
assert sentence_3_index != sentence_1_index and sentence_3_index != sentence_2_index
print("Chosen index:", sentence_3_index)
sentence_3 = all_tagged_sentences[sentence_3_index]
sentence_3_test = test_sents[sentence_3_index]
tree_3 = trigram_chunker.parse(sentence_3)
print("Generated Tree:", tree_3)
"""
(S
  In/IN
  (NP a/DT filing/NN)
  with/IN
  (NP the/DT Securities/NNP)
  and/CC
  (NP Exchange/NNP Commission/NNP)
  ,/,
  (NP Parsow/NNP)
  and/CC
  (NP Elkhorn/NNP)
  ,/,
  (NP which/WDT)
  together/RB
  hold/VB
  (NP 8.685/CD %/NN)
  of/IN
  (NP CACI/NNP)
  (NP 's/POS common/JJ shares/NNS)
  ,/,
  said/VBD
  (NP they/PRP)
  think/VBP
  (NP it/PRP)
  is/VBZ
  in/IN
  (NP the/DT best/JJS interest/NN)
  of/IN
  (NP CACI/NNP stockholders/NNS)
  that/IN
  (NP the/DT company/NN)
  be/VB
  sold/VBN
  ./.)
"""
print("Test Tree:", sentence_3_test)
"""
(S
  In/IN
  (NP a/DT filing/NN)
  with/IN
  (NP the/DT Securities/NNP and/CC Exchange/NNP Commission/NNP)
  ,/,
  (NP Parsow/NNP and/CC Elkhorn/NNP)
  ,/,
  (NP which/WDT)
  together/RB
  hold/VB
  (NP 8.685/CD %/NN)
  of/IN
  (NP CACI/NNP)
  (NP 's/POS common/JJ shares/NNS)
  ,/,
  said/VBD
  (NP they/PRP)
  think/VBP
  (NP it/PRP)
  is/VBZ
  in/IN
  (NP the/DT best/JJS interest/NN)
  of/IN
  (NP CACI/NNP stockholders/NNS)
  that/IN
  (NP the/DT company/NN)
  be/VB
  sold/VBN
  ./.)
"""
"""
Differences Parenthesization:  
Obtained:
(NP the/DT Securities/NNP)
and/CC
(NP Exchange/NNP Commission/NNP)

Expected:
(NP the/DT Securities/NNP and/CC Exchange/NNP Commission/NNP)


Obtained:
(NP Parsow/NNP)
and/CC
(NP Elkhorn/NNP)

Expected:
(NP Parsow/NNP and/CC Elkhorn/NNP)
"""
svgling.draw_tree(tree_3)
# Out:
# Chosen index: 939
# Generated Tree: (S
#   In/IN
#   (NP a/DT filing/NN)
#   with/IN
#   (NP the/DT Securities/NNP)
#   and/CC
#   (NP Exchange/NNP Commission/NNP)
#   ,/,
#   (NP Parsow/NNP)
#   and/CC
#   (NP Elkhorn/NNP)
#   ,/,
#   (NP which/WDT)
#   together/RB
#   hold/VB
#   (NP 8.685/CD %/NN)
#   of/IN
#   (NP CACI/NNP)
#   (NP 's/POS common/JJ shares/NNS)
#   ,/,
#   said/VBD
#   (NP they/PRP)
#   think/VBP
#   (NP it/PRP)
#   is/VBZ
#   in/IN
#   (NP the/DT best/JJS interest/NN)
#   of/IN
#   (NP CACI/NNP stockholders/NNS)
#   that/IN
#   (NP the/DT company/NN)
#   be/VB
#   sold/VBN
#   ./.)
# Test Tree: (S
#   In/IN
#   (NP a/DT filing/NN)
#   with/IN
#   (NP the/DT Securities/NNP and/CC Exchange/NNP Commission/NNP)
#   ,/,
#   (NP Parsow/NNP and/CC Elkhorn/NNP)
#   ,/,
#   (NP which/WDT)
#   together/RB
#   hold/VB
#   (NP 8.685/CD %/NN)
#   of/IN
#   (NP CACI/NNP)
#   (NP 's/POS common/JJ shares/NNS)
#   ,/,
#   said/VBD
#   (NP they/PRP)
#   think/VBP
#   (NP it/PRP)
#   is/VBZ
#   in/IN
#   (NP the/DT best/JJS interest/NN)
#   of/IN
#   (NP CACI/NNP stockholders/NNS)
#   that/IN
#   (NP the/DT company/NN)
#   be/VB
#   sold/VBN
#   ./.)
# TreeLayout(Tree('S', [('In', 'IN'), Tree('NP', [('a', 'DT'), ('filing', 'NN')]), ('with', 'IN'), Tree('NP', [('the', 'DT'), ('Securities', 'NNP')]), ('and', 'CC'), Tree('NP', [('Exchange', 'NNP'), ('Commission', 'NNP')]), (',', ','), Tree('NP', [('Parsow', 'NNP')]), ('and', 'CC'), Tree('NP', [('Elkhorn', 'NNP')]), (',', ','), Tree('NP', [('which', 'WDT')]), ('together', 'RB'), ('hold', 'VB'), Tree('NP', [('8.685', 'CD'), ('%', 'NN')]), ('of', 'IN'), Tree('NP', [('CACI', 'NNP')]), Tree('NP', [("'s", 'POS'), ('common', 'JJ'), ('shares', 'NNS')]), (',', ','), ('said', 'VBD'), Tree('NP', [('they', 'PRP')]), ('think', 'VBP'), Tree('NP', [('it', 'PRP')]), ('is', 'VBZ'), ('in', 'IN'), Tree('NP', [('the', 'DT'), ('best', 'JJS'), ('interest', 'NN')]), ('of', 'IN'), Tree('NP', [('CACI', 'NNP'), ('stockholders', 'NNS')]), ('that', 'IN'), Tree('NP', [('the', 'DT'), ('company', 'NN')]), ('be', 'VB'), ('sold', 'VBN'), ('.', '.')]))

# %% [markdown]
# The obtained trees are identical to the test provided trees.

# %%
from nltk.metrics.distance import edit_distance
for i in range(len(all_tagged_sentences)):
  sentence = all_tagged_sentences[i]
  sentence_test = test_sents[i]
  tree = trigram_chunker.parse(sentence)
  if tree != sentence_test:
    print(i,"^th trees are different", edit_distance(str(tree), str(sentence_test)), "characters")
# Out:
# 2 ^th trees are different 12 characters
# 4 ^th trees are different 30 characters
# 5 ^th trees are different 7 characters
# 6 ^th trees are different 4 characters
# 9 ^th trees are different 22 characters
# 12 ^th trees are different 26 characters
# 14 ^th trees are different 5 characters
# 16 ^th trees are different 4 characters
# 18 ^th trees are different 26 characters
# 19 ^th trees are different 10 characters
# 21 ^th trees are different 23 characters
# 22 ^th trees are different 9 characters
# 24 ^th trees are different 9 characters
# 25 ^th trees are different 20 characters
# 27 ^th trees are different 17 characters
# 29 ^th trees are different 10 characters
# 30 ^th trees are different 5 characters
# 31 ^th trees are different 4 characters
# 32 ^th trees are different 27 characters
# 35 ^th trees are different 14 characters
# 37 ^th trees are different 10 characters
# 38 ^th trees are different 10 characters
# 43 ^th trees are different 13 characters
# 44 ^th trees are different 9 characters
# 49 ^th trees are different 9 characters
# 52 ^th trees are different 14 characters
# 53 ^th trees are different 12 characters
# 54 ^th trees are different 9 characters
# 55 ^th trees are different 9 characters
# 58 ^th trees are different 22 characters
# 59 ^th trees are different 34 characters
# 64 ^th trees are different 29 characters
# 65 ^th trees are different 4 characters
# 67 ^th trees are different 11 characters
# 68 ^th trees are different 19 characters
# 71 ^th trees are different 7 characters
# 72 ^th trees are different 5 characters
# 74 ^th trees are different 9 characters
# 75 ^th trees are different 7 characters
# 76 ^th trees are different 5 characters
# 77 ^th trees are different 9 characters
# 79 ^th trees are different 18 characters
# 82 ^th trees are different 4 characters
# 85 ^th trees are different 24 characters
# 86 ^th trees are different 20 characters
# 87 ^th trees are different 19 characters
# 88 ^th trees are different 10 characters
# 90 ^th trees are different 38 characters
# 91 ^th trees are different 26 characters
# 92 ^th trees are different 7 characters
# 93 ^th trees are different 9 characters
# 95 ^th trees are different 34 characters
# 96 ^th trees are different 24 characters
# 97 ^th trees are different 5 characters
# 98 ^th trees are different 15 characters
# 99 ^th trees are different 21 characters
# 100 ^th trees are different 9 characters
# 102 ^th trees are different 9 characters
# 105 ^th trees are different 41 characters
# 107 ^th trees are different 49 characters
# 108 ^th trees are different 11 characters
# 109 ^th trees are different 9 characters
# 110 ^th trees are different 5 characters
# 111 ^th trees are different 15 characters
# 113 ^th trees are different 10 characters
# 114 ^th trees are different 22 characters
# 115 ^th trees are different 9 characters
# 116 ^th trees are different 34 characters
# 118 ^th trees are different 10 characters
# 119 ^th trees are different 31 characters
# 123 ^th trees are different 10 characters
# 125 ^th trees are different 31 characters
# 128 ^th trees are different 15 characters
# 129 ^th trees are different 20 characters
# 130 ^th trees are different 4 characters
# 131 ^th trees are different 14 characters
# 133 ^th trees are different 19 characters
# 135 ^th trees are different 14 characters
# 136 ^th trees are different 18 characters
# 140 ^th trees are different 9 characters
# 142 ^th trees are different 5 characters
# 143 ^th trees are different 24 characters
# 144 ^th trees are different 48 characters
# 145 ^th trees are different 10 characters
# 146 ^th trees are different 19 characters
# 148 ^th trees are different 9 characters
# 149 ^th trees are different 30 characters
# 150 ^th trees are different 16 characters
# 151 ^th trees are different 5 characters
# 154 ^th trees are different 12 characters
# 155 ^th trees are different 20 characters
# 157 ^th trees are different 9 characters
# 158 ^th trees are different 9 characters
# 159 ^th trees are different 10 characters
# 161 ^th trees are different 12 characters
# 162 ^th trees are different 15 characters
# 163 ^th trees are different 4 characters
# 164 ^th trees are different 5 characters
# 165 ^th trees are different 20 characters
# 166 ^th trees are different 5 characters
# 167 ^th trees are different 14 characters
# 168 ^th trees are different 4 characters
# 171 ^th trees are different 17 characters
# 173 ^th trees are different 7 characters
# 174 ^th trees are different 12 characters
# 176 ^th trees are different 4 characters
# 177 ^th trees are different 5 characters
# 178 ^th trees are different 9 characters
# 179 ^th trees are different 20 characters
# 182 ^th trees are different 14 characters
# 184 ^th trees are different 22 characters
# 186 ^th trees are different 4 characters
# 187 ^th trees are different 23 characters
# 188 ^th trees are different 40 characters
# 190 ^th trees are different 14 characters
# 191 ^th trees are different 7 characters
# 195 ^th trees are different 32 characters
# 196 ^th trees are different 20 characters
# 199 ^th trees are different 5 characters
# 200 ^th trees are different 9 characters
# 201 ^th trees are different 5 characters
# 202 ^th trees are different 15 characters
# 204 ^th trees are different 5 characters
# 205 ^th trees are different 5 characters
# 208 ^th trees are different 5 characters
# 210 ^th trees are different 10 characters
# 211 ^th trees are different 9 characters
# 212 ^th trees are different 8 characters
# 213 ^th trees are different 5 characters
# 215 ^th trees are different 21 characters
# 217 ^th trees are different 9 characters
# 218 ^th trees are different 19 characters
# 220 ^th trees are different 5 characters
# 221 ^th trees are different 5 characters
# 222 ^th trees are different 22 characters
# 223 ^th trees are different 10 characters
# 225 ^th trees are different 10 characters
# 229 ^th trees are different 5 characters
# 230 ^th trees are different 5 characters
# 231 ^th trees are different 21 characters
# 234 ^th trees are different 5 characters
# 236 ^th trees are different 5 characters
# 237 ^th trees are different 4 characters
# 238 ^th trees are different 5 characters
# 241 ^th trees are different 9 characters
# 245 ^th trees are different 9 characters
# 249 ^th trees are different 9 characters
# 250 ^th trees are different 5 characters
# 251 ^th trees are different 10 characters
# 254 ^th trees are different 25 characters
# 255 ^th trees are different 14 characters
# 257 ^th trees are different 10 characters
# 258 ^th trees are different 5 characters
# 259 ^th trees are different 4 characters
# 262 ^th trees are different 5 characters
# 263 ^th trees are different 10 characters
# 264 ^th trees are different 9 characters
# 266 ^th trees are different 10 characters
# 268 ^th trees are different 9 characters
# 270 ^th trees are different 7 characters
# 273 ^th trees are different 12 characters
# 274 ^th trees are different 12 characters
# 276 ^th trees are different 7 characters
# 277 ^th trees are different 16 characters
# 280 ^th trees are different 23 characters
# 284 ^th trees are different 14 characters
# 286 ^th trees are different 17 characters
# 289 ^th trees are different 15 characters
# 291 ^th trees are different 29 characters
# 294 ^th trees are different 26 characters
# 296 ^th trees are different 10 characters
# 298 ^th trees are different 16 characters
# 299 ^th trees are different 7 characters
# 300 ^th trees are different 13 characters
# 301 ^th trees are different 5 characters
# 302 ^th trees are different 4 characters
# 303 ^th trees are different 10 characters
# 304 ^th trees are different 4 characters
# 306 ^th trees are different 5 characters
# 308 ^th trees are different 22 characters
# 310 ^th trees are different 5 characters
# 311 ^th trees are different 10 characters
# 312 ^th trees are different 15 characters
# 314 ^th trees are different 5 characters
# 316 ^th trees are different 27 characters
# 317 ^th trees are different 9 characters
# 318 ^th trees are different 10 characters
# 320 ^th trees are different 7 characters
# 321 ^th trees are different 5 characters
# 322 ^th trees are different 5 characters
# 323 ^th trees are different 9 characters
# 324 ^th trees are different 13 characters
# 326 ^th trees are different 5 characters
# 329 ^th trees are different 5 characters
# 331 ^th trees are different 4 characters
# 333 ^th trees are different 5 characters
# 336 ^th trees are different 9 characters
# 340 ^th trees are different 14 characters
# 342 ^th trees are different 9 characters
# 343 ^th trees are different 7 characters
# 344 ^th trees are different 16 characters
# 347 ^th trees are different 5 characters
# 351 ^th trees are different 10 characters
# 353 ^th trees are different 17 characters
# 354 ^th trees are different 23 characters
# 355 ^th trees are different 29 characters
# 356 ^th trees are different 42 characters
# 357 ^th trees are different 5 characters
# 359 ^th trees are different 5 characters
# 362 ^th trees are different 32 characters
# 363 ^th trees are different 9 characters
# 364 ^th trees are different 9 characters
# 365 ^th trees are different 9 characters
# 370 ^th trees are different 34 characters
# 371 ^th trees are different 4 characters
# 373 ^th trees are different 4 characters
# 374 ^th trees are different 14 characters
# 375 ^th trees are different 10 characters
# 379 ^th trees are different 16 characters
# 382 ^th trees are different 5 characters
# 383 ^th trees are different 5 characters
# 389 ^th trees are different 5 characters
# 392 ^th trees are different 22 characters
# 397 ^th trees are different 14 characters
# 400 ^th trees are different 10 characters
# 403 ^th trees are different 4 characters
# 404 ^th trees are different 4 characters
# 405 ^th trees are different 10 characters
# 407 ^th trees are different 16 characters
# 411 ^th trees are different 5 characters
# 417 ^th trees are different 9 characters
# 419 ^th trees are different 7 characters
# 420 ^th trees are different 9 characters
# 421 ^th trees are different 19 characters
# 422 ^th trees are different 11 characters
# 423 ^th trees are different 14 characters
# 429 ^th trees are different 9 characters
# 431 ^th trees are different 9 characters
# 433 ^th trees are different 5 characters
# 434 ^th trees are different 11 characters
# 437 ^th trees are different 9 characters
# 440 ^th trees are different 24 characters
# 442 ^th trees are different 17 characters
# 444 ^th trees are different 8 characters
# 445 ^th trees are different 15 characters
# 446 ^th trees are different 15 characters
# 450 ^th trees are different 13 characters
# 451 ^th trees are different 10 characters
# 453 ^th trees are different 7 characters
# 454 ^th trees are different 4 characters
# 455 ^th trees are different 13 characters
# 456 ^th trees are different 19 characters
# 457 ^th trees are different 7 characters
# 460 ^th trees are different 9 characters
# 461 ^th trees are different 9 characters
# 462 ^th trees are different 19 characters
# 464 ^th trees are different 9 characters
# 465 ^th trees are different 9 characters
# 466 ^th trees are different 24 characters
# 468 ^th trees are different 5 characters
# 469 ^th trees are different 14 characters
# 471 ^th trees are different 10 characters
# 472 ^th trees are different 19 characters
# 473 ^th trees are different 4 characters
# 474 ^th trees are different 5 characters
# 476 ^th trees are different 10 characters
# 477 ^th trees are different 11 characters
# 478 ^th trees are different 9 characters
# 479 ^th trees are different 9 characters
# 480 ^th trees are different 10 characters
# 481 ^th trees are different 9 characters
# 483 ^th trees are different 23 characters
# 484 ^th trees are different 28 characters
# 486 ^th trees are different 15 characters
# 487 ^th trees are different 15 characters
# 488 ^th trees are different 7 characters
# 489 ^th trees are different 9 characters
# 494 ^th trees are different 11 characters
# 495 ^th trees are different 10 characters
# 497 ^th trees are different 4 characters
# 500 ^th trees are different 23 characters
# 504 ^th trees are different 4 characters
# 505 ^th trees are different 15 characters
# 507 ^th trees are different 19 characters
# 509 ^th trees are different 4 characters
# 512 ^th trees are different 9 characters
# 513 ^th trees are different 4 characters
# 514 ^th trees are different 5 characters
# 519 ^th trees are different 9 characters
# 521 ^th trees are different 28 characters
# 522 ^th trees are different 5 characters
# 523 ^th trees are different 23 characters
# 526 ^th trees are different 4 characters
# 534 ^th trees are different 5 characters
# 535 ^th trees are different 8 characters
# 538 ^th trees are different 5 characters
# 539 ^th trees are different 4 characters
# 540 ^th trees are different 30 characters
# 546 ^th trees are different 15 characters
# 547 ^th trees are different 15 characters
# 548 ^th trees are different 9 characters
# 550 ^th trees are different 9 characters
# 551 ^th trees are different 4 characters
# 553 ^th trees are different 9 characters
# 554 ^th trees are different 10 characters
# 555 ^th trees are different 4 characters
# 557 ^th trees are different 5 characters
# 560 ^th trees are different 9 characters
# 562 ^th trees are different 5 characters
# 563 ^th trees are different 13 characters
# 564 ^th trees are different 8 characters
# 565 ^th trees are different 23 characters
# 567 ^th trees are different 22 characters
# 568 ^th trees are different 9 characters
# 569 ^th trees are different 7 characters
# 570 ^th trees are different 9 characters
# 573 ^th trees are different 12 characters
# 574 ^th trees are different 14 characters
# 575 ^th trees are different 10 characters
# 576 ^th trees are different 24 characters
# 577 ^th trees are different 12 characters
# 578 ^th trees are different 19 characters
# 580 ^th trees are different 13 characters
# 582 ^th trees are different 10 characters
# 583 ^th trees are different 7 characters
# 584 ^th trees are different 14 characters
# 585 ^th trees are different 9 characters
# 586 ^th trees are different 33 characters
# 591 ^th trees are different 5 characters
# 594 ^th trees are different 10 characters
# 596 ^th trees are different 5 characters
# 598 ^th trees are different 4 characters
# 600 ^th trees are different 5 characters
# 605 ^th trees are different 26 characters
# 606 ^th trees are different 5 characters
# 607 ^th trees are different 5 characters
# 609 ^th trees are different 9 characters
# 612 ^th trees are different 5 characters
# 613 ^th trees are different 39 characters
# 614 ^th trees are different 9 characters
# 616 ^th trees are different 5 characters
# 617 ^th trees are different 11 characters
# 618 ^th trees are different 5 characters
# 620 ^th trees are different 14 characters
# 623 ^th trees are different 4 characters
# 625 ^th trees are different 10 characters
# 628 ^th trees are different 7 characters
# 630 ^th trees are different 5 characters
# 633 ^th trees are different 22 characters
# 634 ^th trees are different 9 characters
# 635 ^th trees are different 10 characters
# 637 ^th trees are different 9 characters
# 639 ^th trees are different 15 characters
# 642 ^th trees are different 7 characters
# 649 ^th trees are different 5 characters
# 650 ^th trees are different 5 characters
# 651 ^th trees are different 13 characters
# 653 ^th trees are different 30 characters
# 654 ^th trees are different 22 characters
# 656 ^th trees are different 10 characters
# 660 ^th trees are different 4 characters
# 661 ^th trees are different 18 characters
# 662 ^th trees are different 15 characters
# 664 ^th trees are different 10 characters
# 666 ^th trees are different 27 characters
# 667 ^th trees are different 14 characters
# 668 ^th trees are different 24 characters
# 669 ^th trees are different 17 characters
# 671 ^th trees are different 10 characters
# 672 ^th trees are different 13 characters
# 674 ^th trees are different 13 characters
# 675 ^th trees are different 4 characters
# 676 ^th trees are different 23 characters
# 678 ^th trees are different 18 characters
# 680 ^th trees are different 10 characters
# 681 ^th trees are different 8 characters
# 683 ^th trees are different 9 characters
# 685 ^th trees are different 5 characters
# 687 ^th trees are different 9 characters
# 688 ^th trees are different 20 characters
# 691 ^th trees are different 28 characters
# 692 ^th trees are different 10 characters
# 694 ^th trees are different 10 characters
# 696 ^th trees are different 11 characters
# 697 ^th trees are different 33 characters
# 700 ^th trees are different 5 characters
# 701 ^th trees are different 18 characters
# 702 ^th trees are different 17 characters
# 704 ^th trees are different 22 characters
# 705 ^th trees are different 9 characters
# 707 ^th trees are different 10 characters
# 708 ^th trees are different 17 characters
# 709 ^th trees are different 17 characters
# 711 ^th trees are different 25 characters
# 713 ^th trees are different 5 characters
# 715 ^th trees are different 21 characters
# 716 ^th trees are different 10 characters
# 717 ^th trees are different 10 characters
# 718 ^th trees are different 4 characters
# 720 ^th trees are different 5 characters
# 721 ^th trees are different 38 characters
# 722 ^th trees are different 9 characters
# 723 ^th trees are different 5 characters
# 724 ^th trees are different 12 characters
# 725 ^th trees are different 9 characters
# 728 ^th trees are different 4 characters
# 729 ^th trees are different 9 characters
# 730 ^th trees are different 9 characters
# 731 ^th trees are different 12 characters
# 732 ^th trees are different 4 characters
# 733 ^th trees are different 32 characters
# 734 ^th trees are different 22 characters
# 735 ^th trees are different 7 characters
# 736 ^th trees are different 10 characters
# 737 ^th trees are different 11 characters
# 740 ^th trees are different 5 characters
# 741 ^th trees are different 19 characters
# 742 ^th trees are different 4 characters
# 744 ^th trees are different 9 characters
# 746 ^th trees are different 27 characters
# 748 ^th trees are different 16 characters
# 751 ^th trees are different 9 characters
# 752 ^th trees are different 26 characters
# 753 ^th trees are different 9 characters
# 754 ^th trees are different 12 characters
# 756 ^th trees are different 27 characters
# 757 ^th trees are different 36 characters
# 759 ^th trees are different 4 characters
# 761 ^th trees are different 14 characters
# 762 ^th trees are different 13 characters
# 763 ^th trees are different 10 characters
# 766 ^th trees are different 11 characters
# 768 ^th trees are different 10 characters
# 772 ^th trees are different 17 characters
# 773 ^th trees are different 10 characters
# 775 ^th trees are different 7 characters
# 776 ^th trees are different 7 characters
# 777 ^th trees are different 9 characters
# 779 ^th trees are different 20 characters
# 783 ^th trees are different 7 characters
# 784 ^th trees are different 39 characters
# 785 ^th trees are different 9 characters
# 788 ^th trees are different 9 characters
# 789 ^th trees are different 12 characters
# 790 ^th trees are different 9 characters
# 791 ^th trees are different 22 characters
# 793 ^th trees are different 22 characters
# 794 ^th trees are different 8 characters
# 795 ^th trees are different 5 characters
# 796 ^th trees are different 5 characters
# 797 ^th trees are different 8 characters
# 799 ^th trees are different 8 characters
# 800 ^th trees are different 8 characters
# 801 ^th trees are different 9 characters
# 806 ^th trees are different 31 characters
# 808 ^th trees are different 23 characters
# 809 ^th trees are different 21 characters
# 810 ^th trees are different 28 characters
# 811 ^th trees are different 9 characters
# 814 ^th trees are different 14 characters
# 815 ^th trees are different 5 characters
# 816 ^th trees are different 18 characters
# 819 ^th trees are different 23 characters
# 821 ^th trees are different 9 characters
# 825 ^th trees are different 19 characters
# 827 ^th trees are different 18 characters
# 828 ^th trees are different 28 characters
# 829 ^th trees are different 9 characters
# 831 ^th trees are different 9 characters
# 832 ^th trees are different 19 characters
# 833 ^th trees are different 15 characters
# 834 ^th trees are different 39 characters
# 838 ^th trees are different 20 characters
# 840 ^th trees are different 5 characters
# 841 ^th trees are different 49 characters
# 842 ^th trees are different 4 characters
# 844 ^th trees are different 8 characters
# 845 ^th trees are different 16 characters
# 850 ^th trees are different 13 characters
# 852 ^th trees are different 10 characters
# 853 ^th trees are different 5 characters
# 854 ^th trees are different 9 characters
# 856 ^th trees are different 9 characters
# 858 ^th trees are different 9 characters
# 860 ^th trees are different 28 characters
# 862 ^th trees are different 23 characters
# 863 ^th trees are different 42 characters
# 864 ^th trees are different 5 characters
# 865 ^th trees are different 14 characters
# 868 ^th trees are different 14 characters
# 869 ^th trees are different 4 characters
# 870 ^th trees are different 7 characters
# 871 ^th trees are different 5 characters
# 872 ^th trees are different 9 characters
# 873 ^th trees are different 16 characters
# 878 ^th trees are different 9 characters
# 879 ^th trees are different 7 characters
# 886 ^th trees are different 5 characters
# 888 ^th trees are different 19 characters
# 889 ^th trees are different 5 characters
# 890 ^th trees are different 10 characters
# 892 ^th trees are different 5 characters
# 895 ^th trees are different 5 characters
# 896 ^th trees are different 7 characters
# 899 ^th trees are different 7 characters
# 901 ^th trees are different 19 characters
# 904 ^th trees are different 7 characters
# 906 ^th trees are different 7 characters
# 907 ^th trees are different 10 characters
# 908 ^th trees are different 9 characters
# 909 ^th trees are different 4 characters
# 910 ^th trees are different 5 characters
# 912 ^th trees are different 10 characters
# 913 ^th trees are different 5 characters
# 914 ^th trees are different 24 characters
# 915 ^th trees are different 5 characters
# 916 ^th trees are different 36 characters
# 919 ^th trees are different 9 characters
# 920 ^th trees are different 5 characters
# 921 ^th trees are different 5 characters
# 923 ^th trees are different 5 characters
# 925 ^th trees are different 5 characters
# 927 ^th trees are different 5 characters
# 928 ^th trees are different 16 characters
# 929 ^th trees are different 5 characters
# 930 ^th trees are different 23 characters
# 931 ^th trees are different 5 characters
# 932 ^th trees are different 20 characters
# 938 ^th trees are different 9 characters
# 939 ^th trees are different 18 characters
# 940 ^th trees are different 9 characters
# 942 ^th trees are different 9 characters
# 943 ^th trees are different 18 characters
# 945 ^th trees are different 9 characters
# 947 ^th trees are different 18 characters
# 948 ^th trees are different 9 characters
# 951 ^th trees are different 4 characters
# 955 ^th trees are different 10 characters
# 957 ^th trees are different 9 characters
# 958 ^th trees are different 31 characters
# 959 ^th trees are different 7 characters
# 960 ^th trees are different 29 characters
# 961 ^th trees are different 19 characters
# 962 ^th trees are different 24 characters
# 963 ^th trees are different 15 characters
# 964 ^th trees are different 32 characters
# 965 ^th trees are different 10 characters
# 968 ^th trees are different 5 characters
# 969 ^th trees are different 18 characters
# 970 ^th trees are different 21 characters
# 971 ^th trees are different 7 characters
# 972 ^th trees are different 18 characters
# 974 ^th trees are different 5 characters
# 975 ^th trees are different 19 characters
# 976 ^th trees are different 9 characters
# 979 ^th trees are different 19 characters
# 980 ^th trees are different 7 characters
# 985 ^th trees are different 5 characters
# 986 ^th trees are different 18 characters
# 987 ^th trees are different 15 characters
# 993 ^th trees are different 5 characters
# 995 ^th trees are different 5 characters
# 997 ^th trees are different 5 characters
# 1003 ^th trees are different 9 characters
# 1004 ^th trees are different 7 characters
# 1005 ^th trees are different 5 characters
# 1010 ^th trees are different 18 characters
# 1011 ^th trees are different 41 characters
# 1014 ^th trees are different 10 characters
# 1015 ^th trees are different 27 characters
# 1016 ^th trees are different 9 characters
# 1017 ^th trees are different 10 characters
# 1018 ^th trees are different 30 characters
# 1019 ^th trees are different 5 characters
# 1020 ^th trees are different 34 characters
# 1021 ^th trees are different 9 characters
# 1023 ^th trees are different 19 characters
# 1026 ^th trees are different 9 characters
# 1027 ^th trees are different 17 characters
# 1028 ^th trees are different 8 characters
# 1030 ^th trees are different 4 characters
# 1031 ^th trees are different 4 characters
# 1032 ^th trees are different 21 characters
# 1033 ^th trees are different 31 characters
# 1034 ^th trees are different 14 characters
# 1036 ^th trees are different 7 characters
# 1038 ^th trees are different 19 characters
# 1039 ^th trees are different 4 characters
# 1040 ^th trees are different 50 characters
# 1043 ^th trees are different 23 characters
# 1044 ^th trees are different 52 characters
# 1047 ^th trees are different 16 characters
# 1048 ^th trees are different 40 characters
# 1049 ^th trees are different 27 characters
# 1050 ^th trees are different 41 characters
# 1051 ^th trees are different 4 characters
# 1052 ^th trees are different 9 characters
# 1053 ^th trees are different 14 characters
# 1055 ^th trees are different 11 characters
# 1057 ^th trees are different 5 characters
# 1058 ^th trees are different 49 characters
# 1059 ^th trees are different 28 characters
# 1061 ^th trees are different 9 characters
# 1062 ^th trees are different 5 characters
# 1063 ^th trees are different 4 characters
# 1064 ^th trees are different 9 characters
# 1065 ^th trees are different 13 characters
# 1066 ^th trees are different 4 characters
# 1067 ^th trees are different 9 characters
# 1069 ^th trees are different 18 characters
# 1073 ^th trees are different 12 characters
# 1074 ^th trees are different 29 characters
# 1075 ^th trees are different 15 characters
# 1077 ^th trees are different 15 characters
# 1078 ^th trees are different 24 characters
# 1079 ^th trees are different 15 characters
# 1080 ^th trees are different 9 characters
# 1081 ^th trees are different 10 characters
# 1082 ^th trees are different 13 characters
# 1085 ^th trees are different 5 characters
# 1086 ^th trees are different 14 characters
# 1093 ^th trees are different 14 characters
# 1095 ^th trees are different 10 characters
# 1098 ^th trees are different 9 characters
# 1100 ^th trees are different 37 characters
# 1102 ^th trees are different 5 characters
# 1104 ^th trees are different 56 characters
# 1105 ^th trees are different 5 characters
# 1106 ^th trees are different 22 characters
# 1108 ^th trees are different 20 characters
# 1109 ^th trees are different 9 characters
# 1110 ^th trees are different 7 characters
# 1111 ^th trees are different 9 characters
# 1113 ^th trees are different 5 characters
# 1118 ^th trees are different 5 characters
# 1119 ^th trees are different 7 characters
# 1121 ^th trees are different 24 characters
# 1122 ^th trees are different 4 characters
# 1124 ^th trees are different 12 characters
# 1126 ^th trees are different 9 characters
# 1127 ^th trees are different 15 characters
# 1128 ^th trees are different 10 characters
# 1130 ^th trees are different 15 characters
# 1132 ^th trees are different 8 characters
# 1133 ^th trees are different 5 characters
# 1134 ^th trees are different 9 characters
# 1135 ^th trees are different 11 characters
# 1136 ^th trees are different 4 characters
# 1137 ^th trees are different 14 characters
# 1141 ^th trees are different 27 characters
# 1142 ^th trees are different 5 characters
# 1143 ^th trees are different 4 characters
# 1144 ^th trees are different 10 characters
# 1145 ^th trees are different 8 characters
# 1147 ^th trees are different 5 characters
# 1151 ^th trees are different 15 characters
# 1152 ^th trees are different 10 characters
# 1154 ^th trees are different 5 characters
# 1155 ^th trees are different 4 characters
# 1158 ^th trees are different 5 characters
# 1161 ^th trees are different 20 characters
# 1162 ^th trees are different 10 characters
# 1163 ^th trees are different 42 characters
# 1165 ^th trees are different 9 characters
# 1166 ^th trees are different 9 characters
# 1167 ^th trees are different 18 characters
# 1169 ^th trees are different 17 characters
# 1171 ^th trees are different 5 characters
# 1173 ^th trees are different 27 characters
# 1174 ^th trees are different 27 characters
# 1175 ^th trees are different 14 characters
# 1176 ^th trees are different 21 characters
# 1177 ^th trees are different 4 characters
# 1179 ^th trees are different 10 characters
# 1180 ^th trees are different 24 characters
# 1181 ^th trees are different 5 characters
# 1182 ^th trees are different 9 characters
# 1184 ^th trees are different 5 characters
# 1189 ^th trees are different 9 characters
# 1192 ^th trees are different 4 characters
# 1195 ^th trees are different 8 characters
# 1197 ^th trees are different 25 characters
# 1198 ^th trees are different 31 characters
# 1199 ^th trees are different 33 characters
# 1200 ^th trees are different 10 characters
# 1201 ^th trees are different 38 characters
# 1204 ^th trees are different 7 characters
# 1205 ^th trees are different 5 characters
# 1206 ^th trees are different 9 characters
# 1207 ^th trees are different 9 characters
# 1208 ^th trees are different 5 characters
# 1209 ^th trees are different 15 characters
# 1212 ^th trees are different 22 characters
# 1213 ^th trees are different 5 characters
# 1214 ^th trees are different 4 characters
# 1218 ^th trees are different 23 characters
# 1219 ^th trees are different 5 characters
# 1220 ^th trees are different 26 characters
# 1221 ^th trees are different 18 characters
# 1222 ^th trees are different 7 characters
# 1223 ^th trees are different 8 characters
# 1225 ^th trees are different 25 characters
# 1226 ^th trees are different 10 characters
# 1228 ^th trees are different 9 characters
# 1229 ^th trees are different 10 characters
# 1230 ^th trees are different 22 characters
# 1231 ^th trees are different 12 characters
# 1234 ^th trees are different 4 characters
# 1235 ^th trees are different 21 characters
# 1238 ^th trees are different 16 characters
# 1239 ^th trees are different 13 characters
# 1240 ^th trees are different 5 characters
# 1241 ^th trees are different 9 characters
# 1242 ^th trees are different 14 characters
# 1246 ^th trees are different 5 characters
# 1248 ^th trees are different 5 characters
# 1250 ^th trees are different 20 characters
# 1251 ^th trees are different 5 characters
# 1254 ^th trees are different 6 characters
# 1255 ^th trees are different 7 characters
# 1256 ^th trees are different 7 characters
# 1258 ^th trees are different 22 characters
# 1259 ^th trees are different 12 characters
# 1260 ^th trees are different 12 characters
# 1262 ^th trees are different 33 characters
# 1263 ^th trees are different 10 characters
# 1264 ^th trees are different 7 characters
# 1265 ^th trees are different 7 characters
# 1267 ^th trees are different 7 characters
# 1269 ^th trees are different 14 characters
# 1270 ^th trees are different 9 characters
# 1271 ^th trees are different 28 characters
# 1272 ^th trees are different 10 characters
# 1274 ^th trees are different 16 characters
# 1278 ^th trees are different 12 characters
# 1279 ^th trees are different 26 characters
# 1281 ^th trees are different 9 characters
# 1282 ^th trees are different 4 characters
# 1283 ^th trees are different 12 characters
# 1286 ^th trees are different 15 characters
# 1289 ^th trees are different 5 characters
# 1292 ^th trees are different 5 characters
# 1293 ^th trees are different 18 characters
# 1294 ^th trees are different 5 characters
# 1295 ^th trees are different 14 characters
# 1296 ^th trees are different 9 characters
# 1297 ^th trees are different 10 characters
# 1298 ^th trees are different 9 characters
# 1302 ^th trees are different 4 characters
# 1306 ^th trees are different 5 characters
# 1309 ^th trees are different 5 characters
# 1313 ^th trees are different 4 characters
# 1319 ^th trees are different 9 characters
# 1320 ^th trees are different 11 characters
# 1322 ^th trees are different 22 characters
# 1323 ^th trees are different 10 characters
# 1325 ^th trees are different 5 characters
# 1326 ^th trees are different 23 characters
# 1328 ^th trees are different 9 characters
# 1329 ^th trees are different 12 characters
# 1330 ^th trees are different 10 characters
# 1331 ^th trees are different 5 characters
# 1335 ^th trees are different 10 characters
# 1336 ^th trees are different 19 characters
# 1338 ^th trees are different 19 characters
# 1340 ^th trees are different 35 characters
# 1341 ^th trees are different 5 characters
# 1343 ^th trees are different 41 characters
# 1344 ^th trees are different 18 characters
# 1345 ^th trees are different 9 characters
# 1346 ^th trees are different 19 characters
# 1347 ^th trees are different 9 characters
# 1350 ^th trees are different 9 characters
# 1351 ^th trees are different 10 characters
# 1352 ^th trees are different 4 characters
# 1353 ^th trees are different 45 characters
# 1355 ^th trees are different 5 characters
# 1356 ^th trees are different 5 characters
# 1357 ^th trees are different 5 characters
# 1358 ^th trees are different 38 characters
# 1360 ^th trees are different 14 characters
# 1361 ^th trees are different 12 characters
# 1362 ^th trees are different 12 characters
# 1363 ^th trees are different 24 characters
# 1364 ^th trees are different 19 characters
# 1368 ^th trees are different 5 characters
# 1369 ^th trees are different 9 characters
# 1370 ^th trees are different 10 characters
# 1372 ^th trees are different 10 characters
# 1374 ^th trees are different 9 characters
# 1375 ^th trees are different 4 characters
# 1381 ^th trees are different 5 characters
# 1382 ^th trees are different 25 characters
# 1383 ^th trees are different 5 characters
# 1384 ^th trees are different 28 characters
# 1386 ^th trees are different 9 characters
# 1387 ^th trees are different 14 characters
# 1389 ^th trees are different 10 characters
# 1390 ^th trees are different 15 characters
# 1391 ^th trees are different 26 characters
# 1392 ^th trees are different 7 characters
# 1393 ^th trees are different 10 characters
# 1396 ^th trees are different 7 characters
# 1397 ^th trees are different 9 characters
# 1398 ^th trees are different 7 characters
# 1400 ^th trees are different 4 characters
# 1401 ^th trees are different 5 characters
# 1403 ^th trees are different 15 characters
# 1404 ^th trees are different 10 characters
# 1405 ^th trees are different 14 characters
# 1406 ^th trees are different 12 characters
# 1410 ^th trees are different 13 characters
# 1412 ^th trees are different 9 characters
# 1413 ^th trees are different 5 characters
# 1417 ^th trees are different 10 characters
# 1418 ^th trees are different 7 characters
# 1419 ^th trees are different 9 characters
# 1420 ^th trees are different 5 characters
# 1421 ^th trees are different 9 characters
# 1422 ^th trees are different 5 characters
# 1423 ^th trees are different 13 characters
# 1425 ^th trees are different 10 characters
# 1426 ^th trees are different 10 characters
# 1427 ^th trees are different 18 characters
# 1428 ^th trees are different 7 characters
# 1429 ^th trees are different 9 characters
# 1430 ^th trees are different 5 characters
# 1431 ^th trees are different 12 characters
# 1434 ^th trees are different 22 characters
# 1436 ^th trees are different 12 characters
# 1439 ^th trees are different 23 characters
# 1440 ^th trees are different 19 characters
# 1442 ^th trees are different 5 characters
# 1446 ^th trees are different 5 characters
# 1447 ^th trees are different 4 characters
# 1449 ^th trees are different 10 characters
# 1452 ^th trees are different 10 characters
# 1453 ^th trees are different 10 characters
# 1454 ^th trees are different 7 characters
# 1455 ^th trees are different 22 characters
# 1457 ^th trees are different 7 characters
# 1461 ^th trees are different 10 characters
# 1462 ^th trees are different 19 characters
# 1463 ^th trees are different 5 characters
# 1464 ^th trees are different 14 characters
# 1466 ^th trees are different 13 characters
# 1468 ^th trees are different 5 characters
# 1469 ^th trees are different 29 characters
# 1474 ^th trees are different 5 characters
# 1476 ^th trees are different 10 characters
# 1479 ^th trees are different 5 characters
# 1480 ^th trees are different 23 characters
# 1481 ^th trees are different 9 characters
# 1482 ^th trees are different 18 characters
# 1483 ^th trees are different 5 characters
# 1484 ^th trees are different 14 characters
# 1485 ^th trees are different 5 characters
# 1486 ^th trees are different 12 characters
# 1488 ^th trees are different 2 characters
# 1489 ^th trees are different 5 characters
# 1490 ^th trees are different 7 characters
# 1491 ^th trees are different 5 characters
# 1493 ^th trees are different 27 characters
# 1495 ^th trees are different 10 characters
# 1496 ^th trees are different 21 characters
# 1497 ^th trees are different 14 characters
# 1499 ^th trees are different 5 characters
# 1500 ^th trees are different 25 characters
# 1501 ^th trees are different 4 characters
# 1502 ^th trees are different 12 characters
# 1503 ^th trees are different 51 characters
# 1504 ^th trees are different 9 characters
# 1505 ^th trees are different 14 characters
# 1506 ^th trees are different 19 characters
# 1509 ^th trees are different 9 characters
# 1510 ^th trees are different 22 characters
# 1511 ^th trees are different 5 characters
# 1512 ^th trees are different 26 characters
# 1517 ^th trees are different 10 characters
# 1518 ^th trees are different 38 characters
# 1521 ^th trees are different 48 characters
# 1523 ^th trees are different 14 characters
# 1524 ^th trees are different 4 characters
# 1526 ^th trees are different 5 characters
# 1527 ^th trees are different 10 characters
# 1529 ^th trees are different 15 characters
# 1533 ^th trees are different 10 characters
# 1536 ^th trees are different 15 characters
# 1537 ^th trees are different 5 characters
# 1538 ^th trees are different 9 characters
# 1539 ^th trees are different 39 characters
# 1543 ^th trees are different 9 characters
# 1545 ^th trees are different 13 characters
# 1546 ^th trees are different 4 characters
# 1549 ^th trees are different 7 characters
# 1551 ^th trees are different 9 characters
# 1552 ^th trees are different 14 characters
# 1553 ^th trees are different 18 characters
# 1554 ^th trees are different 10 characters
# 1555 ^th trees are different 4 characters
# 1562 ^th trees are different 7 characters
# 1563 ^th trees are different 5 characters
# 1564 ^th trees are different 10 characters
# 1566 ^th trees are different 7 characters
# 1572 ^th trees are different 9 characters
# 1573 ^th trees are different 5 characters
# 1575 ^th trees are different 14 characters
# 1576 ^th trees are different 16 characters
# 1577 ^th trees are different 11 characters
# 1579 ^th trees are different 7 characters
# 1581 ^th trees are different 14 characters
# 1585 ^th trees are different 10 characters
# 1590 ^th trees are different 5 characters
# 1593 ^th trees are different 7 characters
# 1594 ^th trees are different 10 characters
# 1598 ^th trees are different 9 characters
# 1601 ^th trees are different 22 characters
# 1602 ^th trees are different 36 characters
# 1603 ^th trees are different 5 characters
# 1605 ^th trees are different 16 characters
# 1606 ^th trees are different 10 characters
# 1607 ^th trees are different 10 characters
# 1608 ^th trees are different 16 characters
# 1609 ^th trees are different 5 characters
# 1610 ^th trees are different 4 characters
# 1611 ^th trees are different 5 characters
# 1613 ^th trees are different 26 characters
# 1615 ^th trees are different 16 characters
# 1617 ^th trees are different 9 characters
# 1618 ^th trees are different 9 characters
# 1621 ^th trees are different 4 characters
# 1622 ^th trees are different 18 characters
# 1623 ^th trees are different 10 characters
# 1625 ^th trees are different 9 characters
# 1626 ^th trees are different 28 characters
# 1627 ^th trees are different 4 characters
# 1628 ^th trees are different 13 characters
# 1629 ^th trees are different 38 characters
# 1630 ^th trees are different 15 characters
# 1631 ^th trees are different 8 characters
# 1632 ^th trees are different 10 characters
# 1635 ^th trees are different 33 characters
# 1636 ^th trees are different 12 characters
# 1637 ^th trees are different 23 characters
# 1639 ^th trees are different 10 characters
# 1640 ^th trees are different 33 characters
# 1641 ^th trees are different 20 characters
# 1642 ^th trees are different 4 characters
# 1643 ^th trees are different 26 characters
# 1644 ^th trees are different 25 characters
# 1645 ^th trees are different 10 characters
# 1647 ^th trees are different 9 characters
# 1648 ^th trees are different 10 characters
# 1649 ^th trees are different 4 characters
# 1650 ^th trees are different 15 characters
# 1651 ^th trees are different 7 characters
# 1652 ^th trees are different 5 characters
# 1653 ^th trees are different 7 characters
# 1655 ^th trees are different 10 characters
# 1656 ^th trees are different 31 characters
# 1658 ^th trees are different 5 characters
# 1660 ^th trees are different 4 characters
# 1661 ^th trees are different 11 characters
# 1662 ^th trees are different 10 characters
# 1663 ^th trees are different 23 characters
# 1666 ^th trees are different 14 characters
# 1667 ^th trees are different 5 characters
# 1669 ^th trees are different 15 characters
# 1671 ^th trees are different 7 characters
# 1672 ^th trees are different 7 characters
# 1675 ^th trees are different 9 characters
# 1677 ^th trees are different 15 characters
# 1679 ^th trees are different 10 characters
# 1680 ^th trees are different 26 characters
# 1681 ^th trees are different 51 characters
# 1682 ^th trees are different 12 characters
# 1683 ^th trees are different 5 characters
# 1684 ^th trees are different 27 characters
# 1685 ^th trees are different 4 characters
# 1688 ^th trees are different 5 characters
# 1689 ^th trees are different 5 characters
# 1690 ^th trees are different 5 characters
# 1691 ^th trees are different 9 characters
# 1692 ^th trees are different 9 characters
# 1695 ^th trees are different 5 characters
# 1696 ^th trees are different 14 characters
# 1698 ^th trees are different 12 characters
# 1700 ^th trees are different 9 characters
# 1701 ^th trees are different 25 characters
# 1705 ^th trees are different 10 characters
# 1709 ^th trees are different 35 characters
# 1712 ^th trees are different 31 characters
# 1713 ^th trees are different 4 characters
# 1714 ^th trees are different 18 characters
# 1716 ^th trees are different 19 characters
# 1717 ^th trees are different 18 characters
# 1718 ^th trees are different 18 characters
# 1719 ^th trees are different 10 characters
# 1720 ^th trees are different 6 characters
# 1721 ^th trees are different 9 characters
# 1722 ^th trees are different 22 characters
# 1723 ^th trees are different 14 characters
# 1724 ^th trees are different 22 characters
# 1728 ^th trees are different 27 characters
# 1734 ^th trees are different 30 characters
# 1736 ^th trees are different 15 characters
# 1737 ^th trees are different 5 characters
# 1738 ^th trees are different 21 characters
# 1739 ^th trees are different 5 characters
# 1740 ^th trees are different 12 characters
# 1741 ^th trees are different 10 characters
# 1742 ^th trees are different 26 characters
# 1743 ^th trees are different 17 characters
# 1746 ^th trees are different 5 characters
# 1747 ^th trees are different 7 characters
# 1748 ^th trees are different 5 characters
# 1749 ^th trees are different 10 characters
# 1750 ^th trees are different 38 characters
# 1751 ^th trees are different 5 characters
# 1754 ^th trees are different 10 characters
# 1755 ^th trees are different 7 characters
# 1756 ^th trees are different 7 characters
# 1758 ^th trees are different 41 characters
# 1759 ^th trees are different 19 characters
# 1760 ^th trees are different 4 characters
# 1761 ^th trees are different 12 characters
# 1764 ^th trees are different 13 characters
# 1765 ^th trees are different 23 characters
# 1766 ^th trees are different 4 characters
# 1767 ^th trees are different 35 characters
# 1769 ^th trees are different 5 characters
# 1773 ^th trees are different 48 characters
# 1774 ^th trees are different 7 characters
# 1775 ^th trees are different 10 characters
# 1776 ^th trees are different 15 characters
# 1777 ^th trees are different 32 characters
# 1781 ^th trees are different 51 characters
# 1782 ^th trees are different 10 characters
# 1783 ^th trees are different 18 characters
# 1785 ^th trees are different 13 characters
# 1787 ^th trees are different 5 characters
# 1788 ^th trees are different 10 characters
# 1790 ^th trees are different 9 characters
# 1795 ^th trees are different 9 characters
# 1796 ^th trees are different 9 characters
# 1797 ^th trees are different 10 characters
# 1798 ^th trees are different 10 characters
# 1799 ^th trees are different 18 characters
# 1801 ^th trees are different 7 characters
# 1803 ^th trees are different 4 characters
# 1805 ^th trees are different 10 characters
# 1806 ^th trees are different 7 characters
# 1810 ^th trees are different 4 characters
# 1811 ^th trees are different 17 characters
# 1812 ^th trees are different 10 characters
# 1813 ^th trees are different 12 characters
# 1814 ^th trees are different 18 characters
# 1816 ^th trees are different 28 characters
# 1817 ^th trees are different 9 characters
# 1819 ^th trees are different 9 characters
# 1820 ^th trees are different 19 characters
# 1822 ^th trees are different 19 characters
# 1823 ^th trees are different 18 characters
# 1825 ^th trees are different 9 characters
# 1827 ^th trees are different 10 characters
# 1831 ^th trees are different 15 characters
# 1832 ^th trees are different 9 characters
# 1834 ^th trees are different 9 characters
# 1836 ^th trees are different 5 characters
# 1841 ^th trees are different 10 characters
# 1842 ^th trees are different 9 characters
# 1844 ^th trees are different 23 characters
# 1845 ^th trees are different 4 characters
# 1846 ^th trees are different 20 characters
# 1847 ^th trees are different 14 characters
# 1848 ^th trees are different 28 characters
# 1849 ^th trees are different 5 characters
# 1850 ^th trees are different 7 characters
# 1851 ^th trees are different 4 characters
# 1852 ^th trees are different 9 characters
# 1853 ^th trees are different 9 characters
# 1854 ^th trees are different 9 characters
# 1859 ^th trees are different 15 characters
# 1862 ^th trees are different 7 characters
# 1864 ^th trees are different 15 characters
# 1865 ^th trees are different 16 characters
# 1866 ^th trees are different 7 characters
# 1867 ^th trees are different 9 characters
# 1868 ^th trees are different 20 characters
# 1869 ^th trees are different 7 characters
# 1870 ^th trees are different 33 characters
# 1871 ^th trees are different 7 characters
# 1872 ^th trees are different 7 characters
# 1875 ^th trees are different 12 characters
# 1877 ^th trees are different 44 characters
# 1878 ^th trees are different 10 characters
# 1880 ^th trees are different 10 characters
# 1881 ^th trees are different 10 characters
# 1884 ^th trees are different 4 characters
# 1887 ^th trees are different 26 characters
# 1888 ^th trees are different 5 characters
# 1889 ^th trees are different 30 characters
# 1890 ^th trees are different 28 characters
# 1891 ^th trees are different 29 characters
# 1894 ^th trees are different 9 characters
# 1896 ^th trees are different 17 characters
# 1897 ^th trees are different 5 characters
# 1901 ^th trees are different 5 characters
# 1904 ^th trees are different 9 characters
# 1906 ^th trees are different 4 characters
# 1908 ^th trees are different 30 characters
# 1911 ^th trees are different 7 characters
# 1912 ^th trees are different 7 characters
# 1913 ^th trees are different 10 characters
# 1916 ^th trees are different 26 characters
# 1917 ^th trees are different 9 characters
# 1918 ^th trees are different 5 characters
# 1921 ^th trees are different 16 characters
# 1922 ^th trees are different 10 characters
# 1923 ^th trees are different 9 characters
# 1925 ^th trees are different 14 characters
# 1926 ^th trees are different 28 characters
# 1928 ^th trees are different 16 characters
# 1929 ^th trees are different 10 characters
# 1931 ^th trees are different 9 characters
# 1932 ^th trees are different 30 characters
# 1936 ^th trees are different 20 characters
# 1937 ^th trees are different 10 characters
# 1938 ^th trees are different 21 characters
# 1940 ^th trees are different 9 characters
# 1941 ^th trees are different 4 characters
# 1946 ^th trees are different 9 characters
# 1947 ^th trees are different 11 characters
# 1949 ^th trees are different 5 characters
# 1950 ^th trees are different 4 characters
# 1951 ^th trees are different 10 characters
# 1952 ^th trees are different 5 characters
# 1955 ^th trees are different 7 characters
# 1956 ^th trees are different 7 characters
# 1957 ^th trees are different 9 characters
# 1961 ^th trees are different 4 characters
# 1962 ^th trees are different 10 characters
# 1963 ^th trees are different 5 characters
# 1966 ^th trees are different 12 characters
# 1967 ^th trees are different 15 characters
# 1968 ^th trees are different 19 characters
# 1970 ^th trees are different 7 characters
# 1976 ^th trees are different 15 characters
# 1977 ^th trees are different 21 characters
# 1978 ^th trees are different 24 characters
# 1979 ^th trees are different 19 characters
# 1982 ^th trees are different 4 characters
# 1983 ^th trees are different 7 characters
# 1985 ^th trees are different 24 characters
# 1986 ^th trees are different 38 characters
# 1987 ^th trees are different 25 characters
# 1988 ^th trees are different 10 characters
# 1989 ^th trees are different 9 characters
# 1990 ^th trees are different 4 characters
# 1991 ^th trees are different 5 characters
# 1993 ^th trees are different 9 characters
# 1994 ^th trees are different 15 characters
# 1995 ^th trees are different 16 characters
# 1997 ^th trees are different 18 characters
# 1998 ^th trees are different 20 characters
# 2001 ^th trees are different 5 characters
# 2002 ^th trees are different 10 characters
# 2003 ^th trees are different 5 characters
# 2005 ^th trees are different 15 characters
# 2006 ^th trees are different 34 characters
# 2007 ^th trees are different 11 characters
# 2010 ^th trees are different 7 characters
# 2011 ^th trees are different 5 characters
